# %%
# Remove bibliotecas legadas do Gemini (caso existam)
# %pip uninstall -y google-ai-generativelanguage google-generativeai

# Atualiza ferramentas de instalação
# %pip install -U pip setuptools wheel

# Instala as bibliotecas do projeto
# %pip install -U \
    langchain \
    langchain-core \
    langchain-community \
    langchain-google-genai \
    langchain-pinecone \
    langgraph \
    pinecone \
    arxiv
# Out:
# Found existing installation: google-ai-generativelanguage 0.6.15
# Uninstalling google-ai-generativelanguage-0.6.15:
#   Successfully uninstalled google-ai-generativelanguage-0.6.15
# Found existing installation: google-generativeai 0.8.6
# Uninstalling google-generativeai-0.8.6:
#   Successfully uninstalled google-generativeai-0.8.6
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 26.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
import os
from google.colab import userdata
api_key = userdata.get('projetoiaagente')
os.environ['GOOGLE_API_KEY'] = api_key

# %%
# %pip install langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 2.3 MB/s eta 0:00:00
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite",
    temperature=0
)

# %%
from langchain_core.prompts import PromptTemplate

# %%
modelo_de_prompt = PromptTemplate(
    template="Quais os impactos da IA na Escola {escola}",
    input_variables=['escola']
)

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
cadeia = modelo_de_prompt | llm | StrOutputParser()

# %%
resposta = cadeia.invoke({'escola': 'IFIS'})
print(resposta)
# Out:
# Para analisar os impactos da Inteligência Artificial (IA) na **Escola IFIS** (considerando o contexto de instituições de ensino técnico e profissionalizante que seguem modelos similares aos Institutos Federais ou escolas técnicas de referência), é preciso observar tanto as oportunidades de inovação quanto os desafios pedagógicos e éticos.
#
# Embora o "IFIS" possa se referir a uma instituição específica ou a um modelo de ensino, os impactos da IA nesse ecossistema geralmente se dividem em quatro pilares principais:
#
# ---
#
# ### 1. Personalização da Aprendizagem (Ensino Adaptativo)
# A IA permite que a escola saia do modelo "tamanho único" para um modelo personalizado:
# *   **Tutoria Inteligente:** Plataformas que identificam onde o aluno tem dificuldade (ex: em cálculos de física ou lógica de programação) e oferecem exercícios de reforço específicos para aquela lacuna.
# ...

# %%
# %pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
#importantando o tavily para busca na web
# Out:
# /tmp/ipykernel_955/3138206293.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults

# %%
from langchain_core.tools import tool
#definindo uma ferramenta

# %%
import os
from google.colab import userdata

os.environ["TAVILY_API_KEY"] = userdata.get('meutavili')

# %%
#fazendo uma função usando pré-funcões definidas
@tool
def busca_web(query: str) -> list:
    """Busca na web por um termo específico"""

    tavily_search = TavilySearchResults(
        max_results=2
    )

    resultado_busca = tavily_search.invoke(query)

    return resultado_busca

# %%
resultado = busca_web.invoke("Impactos da IA na escola")

print(resultado)
# Out:
# /tmp/ipykernel_955/529539115.py:6: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tavily_search = TavilySearchResults(
# ...

# %%
tools = [busca_web]

# %%
llm_com_ferramenta = llm.bind(tools=tools)

# %%
modelo_de_prompt = PromptTemplate(
    template="Usando apenas as tools disponíveis me diga quais os impactos da IA na escola {escola}",
    input_variables=["escola"]
)

cadeia = modelo_de_prompt | llm_com_ferramenta | StrOutputParser()

# %%
resposta = cadeia.invoke({"escola": "IFIS"})
resposta
# Out:
# ''

# %%
prompt = """Usando apenas as tools disponíveis me diga quais os impactos da IA no escola IFIS"""
resposta = llm_com_ferramenta.invoke(prompt)

# %%
print(resposta)
 #A LLM percebeu que precisava chamar a ferramenta, mas não gerou uma resposta de forma direta.
# Out:
# content=[] additional_kwargs={'function_call': {'name': 'busca_web', 'arguments': '{"query": "o que \\u00e9 escola IFIS"}'}, '__gemini_function_call_thought_signatures__': {'rBjvCPyJ': 'EjQKMgERTTIPecf9rF0P1auXCEPW23J5R6Re0CieYG7qPniSEgZNa9rU9Dsn0A9/HR4o7Lep'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019f6387-08a6-7510-ad32-eeb04266c46e-0' tool_calls=[{'name': 'busca_web', 'args': {'query': 'o que é escola IFIS'}, 'id': 'rBjvCPyJ', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 84, 'output_tokens': 21, 'total_tokens': 105, 'input_token_details': {'cache_read': 0}}

# %%
from langgraph.prebuilt import create_react_agent

# %%
system_prompt = """ Atue como um assistente útil.
Use as ferramentas fornecidas para responder às perguntas do usuário.
- busca_web: Retorna os resultados de uma busca na web.
Use a busca_web sempre que o usuário fizer uma pergunta sobre um tema específico e retorne o link dos artigos na resposta.
"""

# %%
agente_web = create_react_agent(model=llm, tools=tools, prompt=system_prompt)
# Out:
# /tmp/ipykernel_955/2881733934.py:1: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agente_web = create_react_agent(model=llm, tools=tools, prompt=system_prompt)

# %%
resultado = agente_web.invoke({"messages": [("user", "Quais os impactos da IA na escola")]})

# %%
resultado["messages"][-1]
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'A inteligência artificial (IA) está transformando o ambiente escolar de maneira profunda, trazendo tanto oportunidades significativas quanto desafios que precisam ser gerenciados.\n\nAqui estão os principais impactos da IA na educação:\n\n### Impactos Positivos (Oportunidades)\n\n*   **Personalização do Ensino:** A IA permite adaptar o conteúdo e o ritmo de aprendizagem às necessidades individuais de cada aluno, ajudando aqueles que têm mais dificuldade e desafiando os que estão mais avançados.\n*   **Acessibilidade e Inclusão:** Ferramentas de reconhecimento de fala, tradução automática e outras tecnologias assistivas facilitam o aprendizado para alunos com deficiências físicas, cognitivas ou barreiras linguísticas, promovendo um ambiente mais equitativo.\n*   **Eficiência Administrativa:** A IA pode auxiliar na gestão escolar, desde a captação e retenção de alunos até a automação de tarefas burocráticas, permitindo que educadores foquem 
# ...

# %%
# %pip install -U langchain-community langgraph

# %%
# %pip install arxiv==2.1.0
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 5.1 MB/s eta 0:00:00
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=cbbcb9d5db0b4f985740a99292978797bacc6faedcda083a51d5b8b90a7c50e7
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.34.2
#     Uninstalling requests-2.34.2:
#       Successfully uninstalled requests-2.34.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.4.2 requires requests<3.0.0,>=2.32.5, but you have requests 2.31.0 which is incompatible.
# ...

# %%
from langchain_community.tools.arxiv.tool import ArxivQueryRun

# Criando a ferramenta científica de forma direta e atualizada
tool_cientifica = [ArxivQueryRun()]

# %%
# 1. Defina o texto das instruções do seu agente científico
system_prompt2 = """
Atue como um assistente útil e científico.
- Use as ferramentas fornecidas para responder às perguntas do usuário.
- tool_cientifica: Retorna os resultados de uma busca no arxiv.
Use a tool_cientifica sempre que o usuário fizer uma pergunta sobre um tema específico e retorne o título dos artigos na resposta.
"""

# %%
agente_cientifico = create_react_agent(
    model=llm,
    tools=tool_cientifica,
    prompt=system_prompt2
)
# Out:
# /tmp/ipykernel_955/2835735643.py:1: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agente_cientifico = create_react_agent(

# %%
resultado = agente_cientifico.invoke({"messages": [("user", "AI impact in education")]})

# %%
from typing import TypedDict

# %%
class AgentState(TypedDict):
    user_query: str
    web_answer: str
    scientific_answer: str
    final_answer: str

# %%
def funcao_agente_web(state: AgentState) -> dict:
    """
    Função que executa um agente no estilo ReAct que realiza uma busca na web
    por um termo específico.

    Esta função pega o estado atual do agente (que contém a pergunto do usuário) e
    cria um agente usando o Gemini e a ferramenta tavily e retorna a resposta do agente.

    Args:
        state (AgentState): Um dicionário contendo a pergunta do usuário e a resposta do agente.

    Returns:
        str: A resposta do agente.
    """

# %%
system_prompt = """ Atue como um assistente útil.
Use as ferramentas fornecidas para responder às perguntas do usuário.
- busca_web: Retorna os resultados de uma busca na web.
Use a busca_web sempre que o usuário fizer uma pergunta sobre um tema específico e retorne o link dos artigos na
"""

agente_web = create_react_agent(model=llm, tools=tools, prompt=system_prompt)
resultado = agente_web.invoke({"messages": [("user", state["user_query"])]})
resposta_final = resultado['messages'][-1].content
return {"web_answer": resposta_final}
# Out:
# /tmp/ipykernel_955/92903887.py:7: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agente_web = create_react_agent(model=llm, tools=tools, prompt=system_prompt)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_955/92903887.py in <cell line: 0>()
#       6
#       7 agente_web = create_react_agent(model=llm, tools=tools, prompt=system_prompt)
# ----> 8 resultado = agente_web.invoke({"messages": [("user", state["user_query"])]})
#       9 resposta_final = resultado['messages'][-1].content
#      10 return {"web_answer": resposta_final}
#
# NameError: name 'state' is not defined

# %%
def funcao_agente_cientifico(state: AgentState) -> dict:
    """
    Função que executa um agente no estilo ReAct que realiza uma busca no arxiv
    por um termo específico.

    Esta função pega o estado atual do agente (que contém a pergunta do usuário) e
    cria um agente usando o Gemini e a ferramenta arxiv e retorna a resposta do agente.

    Args:
        state (AgentState): Um dicionário contendo a pergunta do usuário e a resposta do agente.

    Returns:
        str: A resposta do agente.
    """
    system_prompt = """ Atue como um assistente útil.
    Use as ferramentas fornecidas para responder às perguntas do usuário.
    - tool_cientifica: Retorna os resultados de uma busca no arxiv.
    Use a tool_cientifica sempre que o usuário fizer uma pergunta sobre um tema específico e retorne o título dos artigos na resposta.
    """

    agente_cientifico = create_react_agent(llm, tool_cientifica, prompt=system_prompt)
    resultado = agente_cientifico.invoke({"messages": [("user", state["user_query"])]})
    resposta_final = resultado['messages'][-1].content
    return {"scientific_answer": resposta_final}

# %%
import gradio as gr

# %%
def run_graph(user_query):
    """Executa o langGraph com a query do usuário e retorna a resposta final.
    """

# %%
def run_graph(user_query):
    """Executa o langGraph com a query do usuário e retorna a resposta final.
    """
    result = app.invoke({"user_query": user_query})
    return result["final_answer"]

# %%
import gradio as gr


def responder_usuario(pergunta):
    resultado = agente_cientifico.invoke({"messages": [("user", pergunta)]})
    return resultado["messages"][-1].content


caixa_entrada = gr.Textbox(label="Digite sua pergunta:", placeholder="Ex: AI impact in school")
caixa_saida = gr.Textbox(label="Resposta do Agente Científico:")


demo = gr.Interface(
    fn=responder_usuario,
    inputs=caixa_entrada,
    outputs=caixa_saida,
    title="meu agente de pesquisa"
)


demo.launch(debug=True)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://94e20135d262ab7f03.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://94e20135d262ab7f03.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
